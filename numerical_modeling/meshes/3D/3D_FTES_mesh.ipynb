# %% [markdown]
# # 3D mesh to model the full FTES experiment

# %% [markdown]
# This script generates the mesh used in section 3.3.6 (Modelling of FTES experiment) of my master's thesis report.

# %% [markdown]
# ## Generate 2D geometry of domain cross-section

# %%
import gmsh
import numpy as np
from math import cos, sin, pi

# initialize the model
gmsh.initialize()
gmsh.option.setNumber("General.Terminal", 1)

L = 250e-3                     # size of the square
r_hole = 17e-3/2               # radius of the hole
r_tubing_outer = 3.175e-3/2    # outer radius of the tubing
r_tubing_inner = 1e-3/2        # inner radius of the tubing

# Define the points to create the quarter circle
geom = gmsh.model.geo
pc = geom.addPoint(0, 0, 0) 
p1 = geom.addPoint(r_tubing_inner, 0, 0) 
p2 = geom.addPoint(r_tubing_outer, 0, 0) 
p3 = geom.addPoint(r_hole, 0, 0) 
p4 = geom.addPoint(L/2, 0, 0) 
p5 = geom.addPoint(L/2, L/2, 0) 
p6 = geom.addPoint(0, L/2, 0) 
p7 = geom.addPoint(0, r_hole, 0)
p8 = geom.addPoint(0, r_tubing_outer, 0)
p9 = geom.addPoint(0, r_tubing_inner, 0)
p10 = geom.addPoint(r_tubing_inner*cos(pi/4), r_tubing_inner*sin(pi/4), 0)
p11 = geom.addPoint(r_tubing_outer*cos(pi/4), r_tubing_outer*sin(pi/4), 0)
p12 = geom.addPoint(r_hole*cos(pi/4), r_hole*sin(pi/4), 0)

# Define lines from points
l1 = geom.addLine(pc, p1)
l2 = geom.addLine(p1, p2)
l3 = geom.addLine(p2, p3)
l4 = geom.addLine(p3, p4)
l5 = geom.addLine(p4, p5)
l6 = geom.addLine(p5, p6)
l7 = geom.addLine(p6, p7)
l8 = geom.addLine(p7, p8)
l9 = geom.addLine(p8, p9)
l10 = geom.addLine(p9, pc)
l11 = geom.addLine(pc, p10)
l12 = geom.addLine(p10, p11)
l13 = geom.addLine(p11, p12)
l14 = geom.addLine(p12, p5)
c1 = geom.addCircleArc(p1, pc, p10)
c2 = geom.addCircleArc(p10, pc, p9)
c3 = geom.addCircleArc(p2, pc, p11)
c4 = geom.addCircleArc(p11, pc, p8)
c5 = geom.addCircleArc(p3, pc, p12)
c6 = geom.addCircleArc(p12, pc, p7)

# Create curve loops
cl1 = geom.addCurveLoop([l1, c1, c2, l10])
cl2 = geom.addCurveLoop([l2, c3, -l12, -c1])
cl3 = geom.addCurveLoop([l12, c4, l9, -c2])
cl4 = geom.addCurveLoop([l3, c5, -l13, -c3])
cl5 = geom.addCurveLoop([l13, c6, l8, -c4])
cl6 = geom.addCurveLoop([l5, -l14, -c5, l4]) 
cl7 = geom.addCurveLoop([l6, l7, -c6, l14])

# Define transfinite curves as we want a structured mesh
for tag in [c1, c2, c3, c4, c5, c6, l5, l6, l1, l10]:
    geom.mesh.setTransfiniteCurve(tag, 20)
for tag in [l4, l14, l7]:
    geom.mesh.setTransfiniteCurve(tag, 20)
for tag in [l3, l13, l8]:
    geom.mesh.setTransfiniteCurve(tag, 8)
for tag in [l2, l12, l9]:
    geom.mesh.setTransfiniteCurve(tag, 8)
    
# Define surfaces
s_circle_tubing_inner = geom.addPlaneSurface([cl1])
s_circle_tubing_outer_down = geom.addPlaneSurface([cl2])
s_circle_tubing_outer_up = geom.addPlaneSurface([cl3])
s_circle_hole_down = geom.addPlaneSurface([cl4])
s_circle_hole_up = geom.addPlaneSurface([cl5])
s_down = geom.addPlaneSurface([cl6])
s_up = geom.addPlaneSurface([cl7])

# Define transfinite surfaces to get a structured mesh
surface_list = [s_circle_tubing_inner, s_circle_tubing_outer_down, s_circle_tubing_outer_up, s_circle_hole_down, s_circle_hole_up, s_down, s_up]
for surf in surface_list:
    geom.mesh.setTransfiniteSurface(surf)

# Recombine to use quadrilateral elements instead of triangles
for surf in surface_list:
    geom.mesh.setRecombine(2, surf)

# %% [markdown]
# ## Extrude by steps

# %%
# First extrusion (height of L/2)
bottom_top_surf = []
bottom_vol = []
for surf in surface_list:
    bottom = gmsh.model.geo.extrude([(2, surf)], 0, 0, L/2, [1]*20, list(np.around(np.linspace(0, 1, num=21)**(1/2), decimals=3)[1:]), recombine=True)
    bottom_top_surf.append(bottom[0])
    bottom_vol.append(bottom[1][1])

# %%
# Second extrusion (height of 500 microns)
fracture_width = 0.001/2
middle_top_surf = []
middle_vol = []
for i, surf in enumerate(bottom_top_surf):
    middle = gmsh.model.geo.extrude([surf], 0, 0, fracture_width, [20], recombine=True)  #10
    middle_top_surf.append(middle[0])
    middle_vol.append(middle[1][1])
    if i==5:
        right_frac_face = middle[2][1]
    elif i==6:
        up_frac_face = middle[2][1]

# %%
# Third extrusion (height of L/2)
top_top_surf = []
top_vol = []
for surf in middle_top_surf:
    top = gmsh.model.geo.extrude([surf], 0, 0, L/2, [50], recombine=True)
    top_top_surf.append(top[0])
    top_vol.append(top[1][1])

# %% [markdown]
# The interior of the tubing is extruded with an additional height of L/300 to force the temperature gradient to be perpendicular to the Dirichlet boundary condition and thus facilitate the calculation of the energy given by conduction to the system.

# %%
# Fourth extrusion only for the inner circle (height of L/300)
top_extension_top_surf = []
top_extension_vol = []
top_extension = gmsh.model.geo.extrude([top_top_surf[0]], 0, 0, L/300, [20], recombine=True)
top_extension_top_surf = top_extension[0]
top_extension_vol = top_extension[1][1]

# %%
geom.synchronize()

# %% [markdown]
# ## Define volumes for solid materials

# %%
# Metal domain
gmsh.model.addPhysicalGroup(3, top_vol[1:3], 103)
gmsh.model.setPhysicalName(3, 103, 'metal')

# Epoxy domain
gmsh.model.addPhysicalGroup(3, bottom_vol[:5] + top_vol[3:5], 104)
gmsh.model.setPhysicalName(3, 104, 'epoxy')

# Rock domain
gmsh.model.addPhysicalGroup(3, bottom_vol[5:] + top_vol[5:], 105)
gmsh.model.setPhysicalName(3, 105, 'rock')

# %% [markdown]
# ## Define volumes for fluid flow

# %%
# Fluid domain 1 = inside the upper part of the inner tubing
gmsh.model.addPhysicalGroup(3, [top_vol[0], middle_vol[0], top_extension_vol], 106)
gmsh.model.setPhysicalName(3, 106, 'well')

# Fluid domain 2 = inside the fracture
gmsh.model.addPhysicalGroup(3, middle_vol[1:], 107)
gmsh.model.setPhysicalName(3, 107, 'fracture')

# %% [markdown]
# ## Define surfaces for boundary conditions and energy calculations

# %%
# Natural boundary condition (0 flux) on all surfaces except at the well's 
# inlet, where the water temperature is prescribed (Dirichlet boundary 
# condition).
gmsh.model.addPhysicalGroup(2, [top_extension_top_surf[1]], 1)
gmsh.model.setPhysicalName(2, 1, 'inletTemperature')

gmsh.model.addPhysicalGroup(2, [right_frac_face, up_frac_face], 2)
gmsh.model.setPhysicalName(2, 2, 'outletTemperature')

# %% [markdown]
# ## Generate mesh

# %%
# Generate mesh
gmsh.model.mesh.generate(3)

# Save mesh
filename = '3D_FTES_mesh.msh'
gmsh.write(filename)

gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 7 (Line)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Line)
# Info    : [ 10%] Meshing curve 10 (Line)
# Info    : [ 10%] Meshing curve 11 (Line)
# Info    : [ 10%] Meshing curve 12 (Line)
# Info    : [ 10%] Meshing curve 13 (Line)
# Info    : [ 20%] Meshing curve 14 (Line)
# Info    : [ 20%] Meshing curve 15 (Circle)
# Info    : [ 20%] Meshing curve 16 (Circle)
# Info    : [ 20%] Meshing curve 17 (Circle)
# Info    : [ 20%] Meshing curve 18 (Circle)
# Info    : [ 20%] Meshing curve 19 (Circle)
# Info    : [ 20%] Meshing curve 20 (Circle)
# Info    : [ 20%] Meshing curve 22 (Extruded)
# Info    : [ 20%] Meshing curve 23 (Extruded)
# Info    : [ 20%] Meshing curve 24 (Extruded)
# Info    : [ 20%] Meshing curve 25 (Extruded)
# Info    : [ 20%] Meshing curve 27 (Extruded)
# Info    : [ 30%] Meshing curve 28 (Extruded)
# Info    : [ 30%] Meshing curve 32 (Extruded)
# Info    : [ 30%] Meshing curve 36 (Extruded)
# Info    : [ 30%] Meshing curve 44 (Extruded)
# Info    : [ 30%] Meshing curve 45 (Extruded)
# Info    : [ 30%] Meshing curve 46 (Extruded)
# Info    : [ 30%] Meshing curve 50 (Extruded)
# Info    : [ 30%] Meshing curve 54 (Extruded)
# Info    : [ 30%] Meshing curve 67 (Extruded)
# Info    : [ 30%] Meshing curve 68 (Extruded)
# Info    : [ 30%] Meshing curve 76 (Extruded)
# Info    : [ 30%] Meshing curve 88 (Extruded)
# Info    : [ 30%] Meshing curve 89 (Extruded)
# Info    : [ 40%] Meshing curve 90 (Extruded)
# Info    : [ 40%] Meshing curve 94 (Extruded)
# Info    : [ 40%] Meshing curve 98 (Extruded)
# Info    : [ 40%] Meshing curve 111 (Extruded)
# Info    : [ 40%] Meshing curve 112 (Extruded)
# Info    : [ 40%] Meshing curve 120 (Extruded)
# Info    : [ 40%] Meshing curve 132 (Extruded)
# Info    : [ 40%] Meshing curve 133 (Extruded)
# Info    : [ 40%] Meshing curve 135 (Extruded)
# Info    : [ 40%] Meshing curve 137 (Extruded)
# Info    : [ 40%] Meshing curve 138 (Extruded)
# Info    : [ 40%] Meshing curve 154 (Extruded)
# Info    : [ 50%] Meshing curve 155 (Extruded)
# Info    : [ 50%] Meshing curve 160 (Extruded)
# Info    : [ 50%] Meshing curve 176 (Extruded)
# Info    : [ 50%] Meshing curve 177 (Extruded)
# Info    : [ 50%] Meshing curve 178 (Extruded)
# Info    : [ 50%] Meshing curve 179 (Extruded)
# Info    : [ 50%] Meshing curve 181 (Extruded)
# Info    : [ 50%] Meshing curve 182 (Extruded)
# Info    : [ 50%] Meshing curve 186 (Extruded)
# Info    : [ 50%] Meshing curve 190 (Extruded)
# Info    : [ 50%] Meshing curve 198 (Extruded)
# Info    : [ 50%] Meshing curve 199 (Extruded)
# Info    : [ 50%] Meshing curve 200 (Extruded)
# Info    : [ 60%] Meshing curve 204 (Extruded)
# Info    : [ 60%] Meshing curve 208 (Extruded)
# Info    : [ 60%] Meshing curve 221 (Extruded)
# Info    : [ 60%] Meshing curve 222 (Extruded)
# Info    : [ 60%] Meshing curve 230 (Extruded)
# Info    : [ 60%] Meshing curve 242 (Extruded)
# Info    : [ 60%] Meshing curve 243 (Extruded)
# Info    : [ 60%] Meshing curve 244 (Extruded)
# Info    : [ 60%] Meshing curve 248 (Extruded)
# Info    : [ 60%] Meshing curve 252 (Extruded)
# Info    : [ 60%] Meshing curve 265 (Extruded)
# Info    : [ 60%] Meshing curve 266 (Extruded)
# Info    : [ 70%] Meshing curve 274 (Extruded)
# Info    : [ 70%] Meshing curve 286 (Extruded)
# Info    : [ 70%] Meshing curve 287 (Extruded)
# Info    : [ 70%] Meshing curve 289 (Extruded)
# Info    : [ 70%] Meshing curve 291 (Extruded)
# Info    : [ 70%] Meshing curve 292 (Extruded)
# Info    : [ 70%] Meshing curve 308 (Extruded)
# Info    : [ 70%] Meshing curve 309 (Extruded)
# Info    : [ 70%] Meshing curve 314 (Extruded)
# Info    : [ 70%] Meshing curve 330 (Extruded)
# Info    : [ 70%] Meshing curve 331 (Extruded)
# Info    : [ 70%] Meshing curve 332 (Extruded)
# Info    : [ 80%] Meshing curve 333 (Extruded)
# Info    : [ 80%] Meshing curve 335 (Extruded)
# Info    : [ 80%] Meshing curve 336 (Extruded)
# Info    : [ 80%] Meshing curve 340 (Extruded)
# Info    : [ 80%] Meshing curve 344 (Extruded)
# Info    : [ 80%] Meshing curve 352 (Extruded)
# Info    : [ 80%] Meshing curve 353 (Extruded)
# Info    : [ 80%] Meshing curve 354 (Extruded)
# Info    : [ 80%] Meshing curve 358 (Extruded)
# Info    : [ 80%] Meshing curve 362 (Extruded)
# Info    : [ 80%] Meshing curve 375 (Extruded)
# Info    : [ 80%] Meshing curve 376 (Extruded)
# Info    : [ 80%] Meshing curve 384 (Extruded)
# Info    : [ 90%] Meshing curve 396 (Extruded)
# Info    : [ 90%] Meshing curve 397 (Extruded)
# Info    : [ 90%] Meshing curve 398 (Extruded)
# Info    : [ 90%] Meshing curve 402 (Extruded)
# Info    : [ 90%] Meshing curve 406 (Extruded)
# Info    : [ 90%] Meshing curve 419 (Extruded)
# Info    : [ 90%] Meshing curve 420 (Extruded)
# Info    : [ 90%] Meshing curve 428 (Extruded)
# Info    : [ 90%] Meshing curve 440 (Extruded)
# Info    : [ 90%] Meshing curve 441 (Extruded)
# Info    : [ 90%] Meshing curve 443 (Extruded)
# Info    : [ 90%] Meshing curve 445 (Extruded)
# Info    : [100%] Meshing curve 446 (Extruded)
# Info    : [100%] Meshing curve 462 (Extruded)
# Info    : [100%] Meshing curve 463 (Extruded)
# Info    : [100%] Meshing curve 468 (Extruded)
# Info    : [100%] Meshing curve 484 (Extruded)
# Info    : [100%] Meshing curve 485 (Extruded)
# Info    : [100%] Meshing curve 486 (Extruded)
# Info    : [100%] Meshing curve 487 (Extruded)
# Info    : [100%] Meshing curve 489 (Extruded)
# Info    : [100%] Meshing curve 490 (Extruded)
# Info    : [100%] Meshing curve 494 (Extruded)
# Info    : [100%] Meshing curve 498 (Extruded)
# Info    : Done meshing 1D (Wall 0.0012401s, CPU 0.002866s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 10%] Meshing surface 2 (Transfinite)
# Info    : [ 10%] Meshing surface 3 (Transfinite)
# Info    : [ 10%] Meshing surface 4 (Transfinite)
# Info    : [ 10%] Meshing surface 5 (Transfinite)
# Info    : [ 10%] Meshing surface 6 (Transfinite)
# Info    : [ 10%] Meshing surface 7 (Transfinite)
# Info    : [ 10%] Meshing surface 29 (Extruded)
# Info    : [ 10%] Meshing surface 33 (Extruded)
# Info    : [ 10%] Meshing surface 37 (Extruded)
# Info    : [ 20%] Meshing surface 41 (Extruded)
# Info    : [ 20%] Meshing surface 42 (Extruded)
# Info    : [ 20%] Meshing surface 51 (Extruded)
# Info    : [ 20%] Meshing surface 55 (Extruded)
# Info    : [ 20%] Meshing surface 59 (Extruded)
# Info    : [ 20%] Meshing surface 64 (Extruded)
# Info    : [ 20%] Meshing surface 77 (Extruded)
# Info    : [ 20%] Meshing surface 81 (Extruded)
# Info    : [ 20%] Meshing surface 86 (Extruded)
# Info    : [ 30%] Meshing surface 95 (Extruded)
# Info    : [ 30%] Meshing surface 99 (Extruded)
# Info    : [ 30%] Meshing surface 103 (Extruded)
# Info    : [ 30%] Meshing surface 108 (Extruded)
# Info    : [ 30%] Meshing surface 121 (Extruded)
# Info    : [ 30%] Meshing surface 125 (Extruded)
# Info    : [ 30%] Meshing surface 130 (Extruded)
# Info    : [ 30%] Meshing surface 139 (Extruded)
# Info    : [ 30%] Meshing surface 143 (Extruded)
# Info    : [ 40%] Meshing surface 151 (Extruded)
# Info    : [ 40%] Meshing surface 152 (Extruded)
# Info    : [ 40%] Meshing surface 161 (Extruded)
# Info    : [ 40%] Meshing surface 165 (Extruded)
# Info    : [ 40%] Meshing surface 174 (Extruded)
# Info    : [ 40%] Meshing surface 183 (Extruded)
# Info    : [ 40%] Meshing surface 187 (Extruded)
# Info    : [ 40%] Meshing surface 191 (Extruded)
# Info    : [ 40%] Meshing surface 195 (Extruded)
# Info    : [ 50%] Meshing surface 196 (Extruded)
# Info    : [ 50%] Meshing surface 205 (Extruded)
# Info    : [ 50%] Meshing surface 209 (Extruded)
# Info    : [ 50%] Meshing surface 213 (Extruded)
# Info    : [ 50%] Meshing surface 218 (Extruded)
# Info    : [ 50%] Meshing surface 231 (Extruded)
# Info    : [ 50%] Meshing surface 235 (Extruded)
# Info    : [ 50%] Meshing surface 240 (Extruded)
# Info    : [ 50%] Meshing surface 249 (Extruded)
# Info    : [ 60%] Meshing surface 253 (Extruded)
# Info    : [ 60%] Meshing surface 257 (Extruded)
# Info    : [ 60%] Meshing surface 262 (Extruded)
# Info    : [ 60%] Meshing surface 275 (Extruded)
# Info    : [ 60%] Meshing surface 279 (Extruded)
# Info    : [ 60%] Meshing surface 284 (Extruded)
# Info    : [ 60%] Meshing surface 293 (Extruded)
# Info    : [ 60%] Meshing surface 297 (Extruded)
# Info    : [ 60%] Meshing surface 305 (Extruded)
# Info    : [ 70%] Meshing surface 306 (Extruded)
# Info    : [ 70%] Meshing surface 315 (Extruded)
# Info    : [ 70%] Meshing surface 319 (Extruded)
# Info    : [ 70%] Meshing surface 328 (Extruded)
# Info    : [ 70%] Meshing surface 337 (Extruded)
# Info    : [ 70%] Meshing surface 341 (Extruded)
# Info    : [ 70%] Meshing surface 345 (Extruded)
# Info    : [ 70%] Meshing surface 349 (Extruded)
# Info    : [ 70%] Meshing surface 350 (Extruded)
# Info    : [ 80%] Meshing surface 359 (Extruded)
# Info    : [ 80%] Meshing surface 363 (Extruded)
# Info    : [ 80%] Meshing surface 367 (Extruded)
# Info    : [ 80%] Meshing surface 372 (Extruded)
# Info    : [ 80%] Meshing surface 385 (Extruded)
# Info    : [ 80%] Meshing surface 389 (Extruded)
# Info    : [ 80%] Meshing surface 394 (Extruded)
# Info    : [ 80%] Meshing surface 403 (Extruded)
# Info    : [ 80%] Meshing surface 407 (Extruded)
# Info    : [ 90%] Meshing surface 411 (Extruded)
# Info    : [ 90%] Meshing surface 416 (Extruded)
# Info    : [ 90%] Meshing surface 429 (Extruded)
# Info    : [ 90%] Meshing surface 433 (Extruded)
# Info    : [ 90%] Meshing surface 438 (Extruded)
# Info    : [ 90%] Meshing surface 447 (Extruded)
# Info    : [ 90%] Meshing surface 451 (Extruded)
# Info    : [ 90%] Meshing surface 459 (Extruded)
# Info    : [ 90%] Meshing surface 460 (Extruded)
# Info    : [100%] Meshing surface 469 (Extruded)
# Info    : [100%] Meshing surface 473 (Extruded)
# Info    : [100%] Meshing surface 482 (Extruded)
# Info    : [100%] Meshing surface 491 (Extruded)
# Info    : [100%] Meshing surface 495 (Extruded)
# Info    : [100%] Meshing surface 499 (Extruded)
# Info    : [100%] Meshing surface 503 (Extruded)
# Info    : [100%] Meshing surface 504 (Extruded)
# Info    : Done meshing 2D (Wall 0.101388s, CPU 0.098061s)
# Info    : Meshing 3D...
# Info    : Meshing volume 1 (Extruded)
# Info    : Meshing volume 2 (Extruded)
# Info    : Meshing volume 3 (Extruded)
# Info    : Meshing volume 4 (Extruded)
# Info    : Meshing volume 5 (Extruded)
# Info    : Meshing volume 6 (Extruded)
# Info    : Meshing volume 7 (Extruded)
# Info    : Meshing volume 8 (Extruded)
# Info    : Meshing volume 9 (Extruded)
# Info    : Meshing volume 10 (Extruded)
# Info    : Meshing volume 11 (Extruded)
# Info    : Meshing volume 12 (Extruded)
# Info    : Meshing volume 13 (Extruded)
# Info    : Meshing volume 14 (Extruded)
# Info    : Meshing volume 15 (Extruded)
# Info    : Meshing volume 16 (Extruded)
# Info    : Meshing volume 17 (Extruded)
# Info    : Meshing volume 18 (Extruded)
# Info    : Meshing volume 19 (Extruded)
# Info    : Meshing volume 20 (Extruded)
# Info    : Meshing volume 21 (Extruded)
# Info    : Meshing volume 22 (Extruded)
# Info    : Done meshing 3D (Wall 0.312292s, CPU 0.312398s)
# Info    : Optimizing mesh...
# Info    : Done optimizing mesh (Wall 0.00501817s, CPU 0.005295s)
# Info    : 161517 nodes 189460 elements
# Info    : Writing '3D_FTES_mesh.msh'...
# Info    : Done writing '3D_FTES_mesh.msh'
