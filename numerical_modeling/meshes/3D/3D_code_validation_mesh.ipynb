# %% [markdown]
# # 3D mesh to validate the advection-diffusion solver

# %% [markdown]
# This script generates the mesh used in section 3.3.3 (Code validation - Energy balance) of my master's thesis report.

# %% [markdown]
# ## Generate 2D geometry of domain cross-section

# %%
import gmsh
import numpy as np
from math import cos, sin, pi

# initialize the model
gmsh.initialize()
gmsh.option.setNumber("General.Terminal", 1)

L = 250e-3                     # size of the square
r_hole = 17e-3/2               # radius of the hole
r_tubing_outer = 3.175e-3/2    # outer radius of the tubing
r_tubing_inner = 1e-3/2        # inner radius of the tubing

# Define the points to create the square
geom = gmsh.model.geo
p1 = geom.addPoint(-L/2, -L/2, 0)    # upper right corner
p2 = geom.addPoint(L/2, -L/2, 0)     # upper left corner
p3 = geom.addPoint(L/2, L/2, 0)      # lower left corner
p4 = geom.addPoint(-L/2, L/2, 0)     # lower right corner

# Define the points to create the hole circle
pc = geom.addPoint(0, 0, 0)                                   # center of the circle
p6 = geom.addPoint(-r_hole*cos(pi/4), -r_hole*sin(pi/4), 0)   # lower left corner
p7 = geom.addPoint(r_hole*cos(pi/4), -r_hole*sin(pi/4), 0)    # lower right corner
p8 = geom.addPoint(r_hole*cos(pi/4), r_hole*sin(pi/4), 0)     # upper right corner
p9 = geom.addPoint(-r_hole*cos(pi/4), r_hole*sin(pi/4), 0)    # upper left corner

# Define the points to create the outer tubing circle
p10 = geom.addPoint(-r_tubing_outer*cos(pi/4), -r_tubing_outer*sin(pi/4), 0)   # lower left corner
p11 = geom.addPoint(r_tubing_outer*cos(pi/4), -r_tubing_outer*sin(pi/4), 0)    # lower right corner
p12 = geom.addPoint(r_tubing_outer*cos(pi/4), r_tubing_outer*sin(pi/4), 0)     # upper right corner
p13 = geom.addPoint(-r_tubing_outer*cos(pi/4), r_tubing_outer*sin(pi/4), 0)    # upper left corner

# Define the points to create the inner tubing circle
p14 = geom.addPoint(-r_tubing_inner*cos(pi/4), -r_tubing_inner*sin(pi/4), 0)   # lower left corner
p15 = geom.addPoint(r_tubing_inner*cos(pi/4), -r_tubing_inner*sin(pi/4), 0)    # lower right corner
p16 = geom.addPoint(r_tubing_inner*cos(pi/4), r_tubing_inner*sin(pi/4), 0)     # upper right corner
p17 = geom.addPoint(-r_tubing_inner*cos(pi/4), r_tubing_inner*sin(pi/4), 0)    # upper left corner

# Define lines from points
l1 = geom.addLine(p1, p2)
l2 = geom.addLine(p2, p3)
l3 = geom.addLine(p3, p4)
l4 = geom.addLine(p4, p1)
l5 = geom.addLine(p1, p6)
l6 = geom.addLine(p2, p7)
l7 = geom.addLine(p3, p8)
l8 = geom.addLine(p4, p9)
l9 = geom.addLine(p6, p10)
l10 = geom.addLine(p7, p11)
l11 = geom.addLine(p8, p12)
l12 = geom.addLine(p9, p13)
l13 = geom.addLine(p10, p14)
l14 = geom.addLine(p11, p15)
l15 = geom.addLine(p12, p16)
l16 = geom.addLine(p13, p17)
c1 = geom.addCircleArc(p6, pc, p7)
c2 = geom.addCircleArc(p7, pc, p8)
c3 = geom.addCircleArc(p8, pc, p9)
c4 = geom.addCircleArc(p9, pc, p6)
c5 = geom.addCircleArc(p10, pc, p11)
c6 = geom.addCircleArc(p11, pc, p12)
c7 = geom.addCircleArc(p12, pc, p13)
c8 = geom.addCircleArc(p13, pc, p10)
c9 = geom.addCircleArc(p14, pc, p15)
c10 = geom.addCircleArc(p15, pc, p16)
c11 = geom.addCircleArc(p16, pc, p17)
c12 = geom.addCircleArc(p17, pc, p14)

# Create curve loops
cl_circle_tubing_inner = geom.addCurveLoop([c9, c10, c11, c12])
cl_circle_tubing_outer_bottom = geom.addCurveLoop([c5, l14, -c9, -l13])
cl_circle_tubing_outer_right = geom.addCurveLoop([c6, l15, -c10, -l14])
cl_circle_tubing_outer_up = geom.addCurveLoop([c7, l16, -c11, -l15])
cl_circle_tubing_outer_left = geom.addCurveLoop([c8, l13, -c12, -l16])
cl_circle_hole_bottom = geom.addCurveLoop([c1, l10, -c5, -l9])
cl_circle_hole_right = geom.addCurveLoop([c2, l11, -c6, -l10])
cl_circle_hole_up = geom.addCurveLoop([c3, l12, -c7, -l11])
cl_circle_hole_left = geom.addCurveLoop([c4, l9, -c8, -l12])
cl_bottom = geom.addCurveLoop([l1, l6, -c1, -l5])
cl_right = geom.addCurveLoop([l2, l7, -c2, -l6])
cl_up = geom.addCurveLoop([l3, l8, -c3, -l7])
cl_left = geom.addCurveLoop([l4, l5, -c4, -l8])

# Define transfinite curves as we want a structured mesh
for tag in [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, l1, l2, l3, l4]:
    geom.mesh.setTransfiniteCurve(tag, 10)
for tag in [l5, l6, l7, l8]:
    geom.mesh.setTransfiniteCurve(tag, 20)
for tag in [l9, l10, l11, l12]:
    geom.mesh.setTransfiniteCurve(tag, 8)
for tag in [l13, l14, l15, l16]:
    geom.mesh.setTransfiniteCurve(tag, 4)
    
# Define surfaces
s_circle_tubing_inner = geom.addPlaneSurface([cl_circle_tubing_inner])
s_circle_tubing_outer_bottom = geom.addPlaneSurface([cl_circle_tubing_outer_bottom])
s_circle_tubing_outer_right = geom.addPlaneSurface([cl_circle_tubing_outer_right])
s_circle_tubing_outer_up = geom.addPlaneSurface([cl_circle_tubing_outer_up])
s_circle_tubing_outer_left = geom.addPlaneSurface([cl_circle_tubing_outer_left])
s_circle_hole_bottom = geom.addPlaneSurface([cl_circle_hole_bottom])
s_circle_hole_right = geom.addPlaneSurface([cl_circle_hole_right])
s_circle_hole_up = geom.addPlaneSurface([cl_circle_hole_up])
s_circle_hole_left = geom.addPlaneSurface([cl_circle_hole_left])
s_bottom = geom.addPlaneSurface([cl_bottom])
s_right = geom.addPlaneSurface([cl_right])
s_up = geom.addPlaneSurface([cl_up])
s_left = geom.addPlaneSurface([cl_left])

# Define transfinite surfaces to get a structured mesh
surface_list = [s_circle_tubing_inner, s_circle_tubing_outer_bottom, s_circle_tubing_outer_right, s_circle_tubing_outer_up, s_circle_tubing_outer_left,
               s_circle_hole_bottom, s_circle_hole_right, s_circle_hole_up, s_circle_hole_left,
               s_bottom, s_right, s_up, s_left]
for surf in surface_list:
    geom.mesh.setTransfiniteSurface(surf)

# Recombine to use quadrilateral elements instead of triangles
for surf in surface_list:
    geom.mesh.setRecombine(2, surf)

# %% [markdown]
# ## Extrude by steps

# %%
# Extrude the surface to a total height of L/2
top_top_surf = []
top_vol = []
for surf in surface_list:
    top = gmsh.model.geo.extrude([(2, surf)], 0, 0, L/2, [60], recombine=True)
    top_top_surf.append(top[0])
    top_vol.append(top[1][1])

# %% [markdown]
# The interior of the tubing is extruded with an additional height of L/300 to force the temperature gradient to be perpendicular to the Dirichlet boundary condition and thus facilitate the calculation of the energy given by conduction to the system.

# %%
top_extension_top_surf = []
top_extension_vol = []
top_extension = gmsh.model.geo.extrude([top_top_surf[0]], 0, 0, L/300, [20], recombine=True)
top_extension_top_surf = top_extension[0]
top_extension_vol = top_extension[1][1]

# %%
geom.synchronize()

# %% [markdown]
# ## Define volumes for solid materials

# %%
# Metal domain
gmsh.model.addPhysicalGroup(3, top_vol[1:5], 103)
gmsh.model.setPhysicalName(3, 103, 'metal')

# Epoxy domain
gmsh.model.addPhysicalGroup(3, top_vol[5:9], 104)
gmsh.model.setPhysicalName(3, 104, 'epoxy')

# Rock domain
gmsh.model.addPhysicalGroup(3, top_vol[9:], 105)
gmsh.model.setPhysicalName(3, 105, 'rock')

# %% [markdown]
# ## Define volumes for fluid flow

# %%
# Fluid domain = inside the inner tubing
gmsh.model.addPhysicalGroup(3, [top_vol[0], top_extension_vol], 106)
gmsh.model.setPhysicalName(3, 106, 'well')

# %% [markdown]
# ## Define surfaces for boundary conditions and energy calculations

# %%
# Natural boundary condition (0 flux) on all surfaces except at the well's 
# inlet, where the water temperature is prescribed (Dirichlet boundary 
# condition).
gmsh.model.addPhysicalGroup(2, [top_extension_top_surf[1]], 1)
gmsh.model.setPhysicalName(2, 1, 'inletTemperature')

gmsh.model.addPhysicalGroup(2, [s_circle_tubing_inner], 2)
gmsh.model.setPhysicalName(2, 2, 'outletTemperature')

# %% [markdown]
# ## Generate mesh

# %%
# Generate mesh
gmsh.option.setNumber('Mesh.SurfaceFaces', 1)
gmsh.option.setNumber('Mesh.Points', 1)
gmsh.model.mesh.generate(3)

# Set the order of the elements
gmsh.model.mesh.setOrder(1)

# Save mesh
filename = '3D_code_validation_mesh.msh'
gmsh.write(filename)

gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 7 (Line)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Line)
# Info    : [ 20%] Meshing curve 10 (Line)
# Info    : [ 20%] Meshing curve 11 (Line)
# Info    : [ 20%] Meshing curve 12 (Line)
# Info    : [ 20%] Meshing curve 13 (Line)
# Info    : [ 20%] Meshing curve 14 (Line)
# Info    : [ 20%] Meshing curve 15 (Line)
# Info    : [ 20%] Meshing curve 16 (Line)
# Info    : [ 20%] Meshing curve 17 (Circle)
# Info    : [ 30%] Meshing curve 18 (Circle)
# Info    : [ 30%] Meshing curve 19 (Circle)
# Info    : [ 30%] Meshing curve 20 (Circle)
# Info    : [ 30%] Meshing curve 21 (Circle)
# Info    : [ 30%] Meshing curve 22 (Circle)
# Info    : [ 30%] Meshing curve 23 (Circle)
# Info    : [ 30%] Meshing curve 24 (Circle)
# Info    : [ 30%] Meshing curve 25 (Circle)
# Info    : [ 40%] Meshing curve 26 (Circle)
# Info    : [ 40%] Meshing curve 27 (Circle)
# Info    : [ 40%] Meshing curve 28 (Circle)
# Info    : [ 40%] Meshing curve 30 (Extruded)
# Info    : [ 40%] Meshing curve 31 (Extruded)
# Info    : [ 40%] Meshing curve 32 (Extruded)
# Info    : [ 40%] Meshing curve 33 (Extruded)
# Info    : [ 40%] Meshing curve 35 (Extruded)
# Info    : [ 50%] Meshing curve 36 (Extruded)
# Info    : [ 50%] Meshing curve 40 (Extruded)
# Info    : [ 50%] Meshing curve 44 (Extruded)
# Info    : [ 50%] Meshing curve 52 (Extruded)
# Info    : [ 50%] Meshing curve 53 (Extruded)
# Info    : [ 50%] Meshing curve 55 (Extruded)
# Info    : [ 50%] Meshing curve 57 (Extruded)
# Info    : [ 50%] Meshing curve 58 (Extruded)
# Info    : [ 60%] Meshing curve 74 (Extruded)
# Info    : [ 60%] Meshing curve 75 (Extruded)
# Info    : [ 60%] Meshing curve 80 (Extruded)
# Info    : [ 60%] Meshing curve 96 (Extruded)
# Info    : [ 60%] Meshing curve 97 (Extruded)
# Info    : [ 60%] Meshing curve 102 (Extruded)
# Info    : [ 60%] Meshing curve 118 (Extruded)
# Info    : [ 60%] Meshing curve 140 (Extruded)
# Info    : [ 70%] Meshing curve 141 (Extruded)
# Info    : [ 70%] Meshing curve 143 (Extruded)
# Info    : [ 70%] Meshing curve 145 (Extruded)
# Info    : [ 70%] Meshing curve 146 (Extruded)
# Info    : [ 70%] Meshing curve 162 (Extruded)
# Info    : [ 70%] Meshing curve 163 (Extruded)
# Info    : [ 70%] Meshing curve 168 (Extruded)
# Info    : [ 70%] Meshing curve 184 (Extruded)
# Info    : [ 80%] Meshing curve 185 (Extruded)
# Info    : [ 80%] Meshing curve 190 (Extruded)
# Info    : [ 80%] Meshing curve 206 (Extruded)
# Info    : [ 80%] Meshing curve 228 (Extruded)
# Info    : [ 80%] Meshing curve 229 (Extruded)
# Info    : [ 80%] Meshing curve 231 (Extruded)
# Info    : [ 80%] Meshing curve 233 (Extruded)
# Info    : [ 80%] Meshing curve 234 (Extruded)
# Info    : [ 90%] Meshing curve 250 (Extruded)
# Info    : [ 90%] Meshing curve 251 (Extruded)
# Info    : [ 90%] Meshing curve 256 (Extruded)
# Info    : [ 90%] Meshing curve 272 (Extruded)
# Info    : [ 90%] Meshing curve 273 (Extruded)
# Info    : [ 90%] Meshing curve 278 (Extruded)
# Info    : [ 90%] Meshing curve 294 (Extruded)
# Info    : [ 90%] Meshing curve 316 (Extruded)
# Info    : [100%] Meshing curve 317 (Extruded)
# Info    : [100%] Meshing curve 318 (Extruded)
# Info    : [100%] Meshing curve 319 (Extruded)
# Info    : [100%] Meshing curve 321 (Extruded)
# Info    : [100%] Meshing curve 322 (Extruded)
# Info    : [100%] Meshing curve 326 (Extruded)
# Info    : [100%] Meshing curve 330 (Extruded)
# Info    : Done meshing 1D (Wall 0.0017343s, CPU 0.002928s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 10%] Meshing surface 2 (Transfinite)
# Info    : [ 10%] Meshing surface 3 (Transfinite)
# Info    : [ 10%] Meshing surface 4 (Transfinite)
# Info    : [ 10%] Meshing surface 5 (Transfinite)
# Info    : [ 10%] Meshing surface 6 (Transfinite)
# Info    : [ 20%] Meshing surface 7 (Transfinite)
# Info    : [ 20%] Meshing surface 8 (Transfinite)
# Info    : [ 20%] Meshing surface 9 (Transfinite)
# Info    : [ 20%] Meshing surface 10 (Transfinite)
# Info    : [ 20%] Meshing surface 11 (Transfinite)
# Info    : [ 20%] Meshing surface 12 (Transfinite)
# Info    : [ 30%] Meshing surface 13 (Transfinite)
# Info    : [ 30%] Meshing surface 37 (Extruded)
# Info    : [ 30%] Meshing surface 41 (Extruded)
# Info    : [ 30%] Meshing surface 45 (Extruded)
# Info    : [ 30%] Meshing surface 49 (Extruded)
# Info    : [ 30%] Meshing surface 50 (Extruded)
# Info    : [ 40%] Meshing surface 59 (Extruded)
# Info    : [ 40%] Meshing surface 63 (Extruded)
# Info    : [ 40%] Meshing surface 71 (Extruded)
# Info    : [ 40%] Meshing surface 72 (Extruded)
# Info    : [ 40%] Meshing surface 81 (Extruded)
# Info    : [ 40%] Meshing surface 85 (Extruded)
# Info    : [ 50%] Meshing surface 94 (Extruded)
# Info    : [ 50%] Meshing surface 103 (Extruded)
# Info    : [ 50%] Meshing surface 107 (Extruded)
# Info    : [ 50%] Meshing surface 116 (Extruded)
# Info    : [ 50%] Meshing surface 125 (Extruded)
# Info    : [ 50%] Meshing surface 138 (Extruded)
# Info    : [ 60%] Meshing surface 147 (Extruded)
# Info    : [ 60%] Meshing surface 151 (Extruded)
# Info    : [ 60%] Meshing surface 159 (Extruded)
# Info    : [ 60%] Meshing surface 160 (Extruded)
# Info    : [ 60%] Meshing surface 169 (Extruded)
# Info    : [ 60%] Meshing surface 173 (Extruded)
# Info    : [ 70%] Meshing surface 182 (Extruded)
# Info    : [ 70%] Meshing surface 191 (Extruded)
# Info    : [ 70%] Meshing surface 195 (Extruded)
# Info    : [ 70%] Meshing surface 204 (Extruded)
# Info    : [ 70%] Meshing surface 213 (Extruded)
# Info    : [ 70%] Meshing surface 226 (Extruded)
# Info    : [ 80%] Meshing surface 235 (Extruded)
# Info    : [ 80%] Meshing surface 239 (Extruded)
# Info    : [ 80%] Meshing surface 247 (Extruded)
# Info    : [ 80%] Meshing surface 248 (Extruded)
# Info    : [ 80%] Meshing surface 257 (Extruded)
# Info    : [ 80%] Meshing surface 261 (Extruded)
# Info    : [ 90%] Meshing surface 270 (Extruded)
# Info    : [ 90%] Meshing surface 279 (Extruded)
# Info    : [ 90%] Meshing surface 283 (Extruded)
# Info    : [ 90%] Meshing surface 292 (Extruded)
# Info    : [ 90%] Meshing surface 301 (Extruded)
# Info    : [ 90%] Meshing surface 314 (Extruded)
# Info    : [100%] Meshing surface 323 (Extruded)
# Info    : [100%] Meshing surface 327 (Extruded)
# Info    : [100%] Meshing surface 331 (Extruded)
# Info    : [100%] Meshing surface 335 (Extruded)
# Info    : [100%] Meshing surface 336 (Extruded)
# Info    : Done meshing 2D (Wall 0.0601201s, CPU 0.06196s)
# Info    : Meshing 3D...
# Info    : Meshing volume 1 (Extruded)
# Info    : Meshing volume 2 (Extruded)
# Info    : Meshing volume 3 (Extruded)
# Info    : Meshing volume 4 (Extruded)
# Info    : Meshing volume 5 (Extruded)
# Info    : Meshing volume 6 (Extruded)
# Info    : Meshing volume 7 (Extruded)
# Info    : Meshing volume 8 (Extruded)
# Info    : Meshing volume 9 (Extruded)
# Info    : Meshing volume 10 (Extruded)
# Info    : Meshing volume 11 (Extruded)
# Info    : Meshing volume 12 (Extruded)
# Info    : Meshing volume 13 (Extruded)
# Info    : Meshing volume 14 (Extruded)
# Info    : Done meshing 3D (Wall 0.136655s, CPU 0.133183s)
# Info    : Optimizing mesh...
# Info    : Done optimizing mesh (Wall 0.0020372s, CPU 0.002073s)
# Info    : 71787 nodes 89406 elements
# Info    : Writing '3D_code_validation_mesh.msh'...
# Info    : Done writing '3D_code_validation_mesh.msh'
