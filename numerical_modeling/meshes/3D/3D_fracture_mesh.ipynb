# %% [markdown]
# # 3D mesh to study the heat transfer along the fracture

# %% [markdown]
# This script generates the mesh used in section 3.3.5 (Heat transfer along fracture) of my master's thesis report.

# %% [markdown]
# ## Generate 2D geometry of domain cross-section

# %%
import gmsh
import numpy as np
from math import cos, sin, pi

# initialize the model
gmsh.initialize()
gmsh.option.setNumber("General.Terminal", 1)

L = 250e-3                     # 1/2 of the square size
r_hole = 17e-3/2               # radius of the hole
r_tubing_outer = 3.175e-3/2    # outer radius of the tubing
r_tubing_inner = 1e-3/2        # inner radius of the tubing

# Define the points to create the square
geom = gmsh.model.geo
p1 = geom.addPoint(-L/2*2, -L/2*2, 0)    # upper right corner
p2 = geom.addPoint(L/2*2, -L/2*2, 0)     # upper left corner
p3 = geom.addPoint(L/2*2, L/2*2, 0)      # lower left corner
p4 = geom.addPoint(-L/2*2, L/2*2, 0)     # lower right corner

# Define the points to create the hole circle
pc = geom.addPoint(0, 0, 0)                                   # center of the circle
p6 = geom.addPoint(-r_hole*cos(pi/4), -r_hole*sin(pi/4), 0)   # lower left corner
p7 = geom.addPoint(r_hole*cos(pi/4), -r_hole*sin(pi/4), 0)    # lower right corner
p8 = geom.addPoint(r_hole*cos(pi/4), r_hole*sin(pi/4), 0)     # upper right corner
p9 = geom.addPoint(-r_hole*cos(pi/4), r_hole*sin(pi/4), 0)    # upper left corner

# Define the points to create the outer tubing circle
p10 = geom.addPoint(-r_tubing_outer*cos(pi/4), -r_tubing_outer*sin(pi/4), 0)   # lower left corner
p11 = geom.addPoint(r_tubing_outer*cos(pi/4), -r_tubing_outer*sin(pi/4), 0)    # lower right corner
p12 = geom.addPoint(r_tubing_outer*cos(pi/4), r_tubing_outer*sin(pi/4), 0)     # upper right corner
p13 = geom.addPoint(-r_tubing_outer*cos(pi/4), r_tubing_outer*sin(pi/4), 0)    # upper left corner

# Define the points to create the inner tubing circle
p14 = geom.addPoint(-r_tubing_inner*cos(pi/4), -r_tubing_inner*sin(pi/4), 0)   # lower left corner
p15 = geom.addPoint(r_tubing_inner*cos(pi/4), -r_tubing_inner*sin(pi/4), 0)    # lower right corner
p16 = geom.addPoint(r_tubing_inner*cos(pi/4), r_tubing_inner*sin(pi/4), 0)     # upper right corner
p17 = geom.addPoint(-r_tubing_inner*cos(pi/4), r_tubing_inner*sin(pi/4), 0)    # upper left corner

# Define lines from points
l1 = geom.addLine(p1, p2)
l2 = geom.addLine(p2, p3)
l3 = geom.addLine(p3, p4)
l4 = geom.addLine(p4, p1)
l5 = geom.addLine(p1, p6)
l6 = geom.addLine(p2, p7)
l7 = geom.addLine(p3, p8)
l8 = geom.addLine(p4, p9)
l9 = geom.addLine(p6, p10)
l10 = geom.addLine(p7, p11)
l11 = geom.addLine(p8, p12)
l12 = geom.addLine(p9, p13)
l13 = geom.addLine(p10, p14)
l14 = geom.addLine(p11, p15)
l15 = geom.addLine(p12, p16)
l16 = geom.addLine(p13, p17)
c1 = geom.addCircleArc(p6, pc, p7)
c2 = geom.addCircleArc(p7, pc, p8)
c3 = geom.addCircleArc(p8, pc, p9)
c4 = geom.addCircleArc(p9, pc, p6)
c5 = geom.addCircleArc(p10, pc, p11)
c6 = geom.addCircleArc(p11, pc, p12)
c7 = geom.addCircleArc(p12, pc, p13)
c8 = geom.addCircleArc(p13, pc, p10)
c9 = geom.addCircleArc(p14, pc, p15)
c10 = geom.addCircleArc(p15, pc, p16)
c11 = geom.addCircleArc(p16, pc, p17)
c12 = geom.addCircleArc(p17, pc, p14)

# Create curve loops
cl_circle_tubing_outer_bottom = geom.addCurveLoop([c5, l14, -c9, -l13])
cl_circle_tubing_outer_right = geom.addCurveLoop([c6, l15, -c10, -l14])
cl_circle_tubing_outer_up = geom.addCurveLoop([c7, l16, -c11, -l15])
cl_circle_tubing_outer_left = geom.addCurveLoop([c8, l13, -c12, -l16])
cl_circle_hole_bottom = geom.addCurveLoop([c1, l10, -c5, -l9])
cl_circle_hole_right = geom.addCurveLoop([c2, l11, -c6, -l10])
cl_circle_hole_up = geom.addCurveLoop([c3, l12, -c7, -l11])
cl_circle_hole_left = geom.addCurveLoop([c4, l9, -c8, -l12])
cl_bottom = geom.addCurveLoop([l1, l6, -c1, -l5])
cl_right = geom.addCurveLoop([l2, l7, -c2, -l6])
cl_up = geom.addCurveLoop([l3, l8, -c3, -l7])
cl_left = geom.addCurveLoop([l4, l5, -c4, -l8])

# Define transfinite curves as we want a structured mesh
for tag in [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10, c11, c12, l1, l2, l3, l4]:
    geom.mesh.setTransfiniteCurve(tag, 20)
for tag in [l5, l6, l7, l8]:
    geom.mesh.setTransfiniteCurve(tag, 20*2)
for tag in [l9, l10, l11, l12]:
    geom.mesh.setTransfiniteCurve(tag, 8)
for tag in [l13, l14, l15, l16]:
    geom.mesh.setTransfiniteCurve(tag, 4)
    
# Define surfaces
s_circle_tubing_outer_bottom = geom.addPlaneSurface([cl_circle_tubing_outer_bottom])
s_circle_tubing_outer_right = geom.addPlaneSurface([cl_circle_tubing_outer_right])
s_circle_tubing_outer_up = geom.addPlaneSurface([cl_circle_tubing_outer_up])
s_circle_tubing_outer_left = geom.addPlaneSurface([cl_circle_tubing_outer_left])
s_circle_hole_bottom = geom.addPlaneSurface([cl_circle_hole_bottom])
s_circle_hole_right = geom.addPlaneSurface([cl_circle_hole_right])
s_circle_hole_up = geom.addPlaneSurface([cl_circle_hole_up])
s_circle_hole_left = geom.addPlaneSurface([cl_circle_hole_left])
s_bottom = geom.addPlaneSurface([cl_bottom])
s_right = geom.addPlaneSurface([cl_right])
s_up = geom.addPlaneSurface([cl_up])
s_left = geom.addPlaneSurface([cl_left])


# Define transfinite surfaces to get a structured mesh
surface_list = [s_circle_tubing_outer_bottom, s_circle_tubing_outer_right, s_circle_tubing_outer_up, s_circle_tubing_outer_left,
               s_circle_hole_bottom, s_circle_hole_right, s_circle_hole_up, s_circle_hole_left,
               s_bottom, s_right, s_up, s_left]
for surf in surface_list:
    geom.mesh.setTransfiniteSurface(surf)

# Recombine to use quadrilateral elements instead of triangles
for surf in surface_list:
    geom.mesh.setRecombine(2, surf)

# %% [markdown]
# ## Extrude by steps

# %%
# First extrusion (height of L)
bottom_top_surf = []
bottom_vol = []
for surf in surface_list:
    bottom = gmsh.model.geo.extrude([(2, surf)], 0, 0, L/2*2, [1]*50, list(np.around(np.linspace(0, 1, num=41)**(1/2), decimals=3)[1:]), recombine=True)
    bottom_top_surf.append(bottom[0])
    bottom_vol.append(bottom[1][1])

# %%
# Second extrusion (height of 500 microns)
fracture_width = 0.001/2
middle_top_surf = []
middle_vol = []
for i, surf in enumerate(bottom_top_surf):
    middle = gmsh.model.geo.extrude([surf], 0, 0, fracture_width, [5], recombine=True)
    middle_top_surf.append(middle[0])
    middle_vol.append(middle[1][1])
    if i==0:
        bottom_inner_frac_face = middle[2][1]
    elif i==1:
        right_inner_frac_face = middle[2][1]
    elif i==2:
        up_inner_frac_face = middle[2][1]
    elif i==3:
        left_inner_frac_face = middle[2][1]
    elif i==8:
        bottom_outer_frac_face = middle[2][1]
    elif i==9:
        right_outer_frac_face = middle[2][1]
    elif i==10:
        up_outer_frac_face = middle[2][1]
    elif i==11:
        left_outer_frac_face = middle[2][1]

# %%
# Third extrusion (height of L)
top_top_surf = []
top_vol = []
for surf in middle_top_surf:
    top = gmsh.model.geo.extrude([surf], 0, 0, L/2*2, [1]*50, list(np.around(np.linspace(0, 1, num=41)**(2), decimals=3)[1:]), recombine=True)
    top_top_surf.append(top[0])
    top_vol.append(top[1][1])

# %%
geom.synchronize()

# %% [markdown]
# ## Define volumes for solid materials

# %%
# Metal domain
gmsh.model.addPhysicalGroup(3, top_vol[0:4], 103)
gmsh.model.setPhysicalName(3, 103, 'metal')

# Epoxy domain
gmsh.model.addPhysicalGroup(3, bottom_vol[:8] +  top_vol[4:8], 104)
gmsh.model.setPhysicalName(3, 104, 'epoxy')

# Rock domain
gmsh.model.addPhysicalGroup(3, bottom_vol[8:] + top_vol[8:], 105)
gmsh.model.setPhysicalName(3, 105, 'rock')

# %% [markdown]
# ## Define volumes for fluid flow

# %%
# Fluid domain = inside the fracture
gmsh.model.addPhysicalGroup(3, middle_vol[0:], 107)
gmsh.model.setPhysicalName(3, 107, 'fracture')

# %% [markdown]
# ## Define surfaces for boundary conditions

# %%
# Natural boundary condition (0 flux) on all surfaces except on the inner
# surface of the tubing within the fracture volume (second extrusion), where 
# the water temperature is prescribed (Dirichlet boundary condition).
gmsh.model.addPhysicalGroup(2, [bottom_inner_frac_face, right_inner_frac_face, up_inner_frac_face, left_inner_frac_face], 1)
gmsh.model.setPhysicalName(2, 1, 'inletTemperature')

gmsh.model.addPhysicalGroup(2, [bottom_outer_frac_face, right_outer_frac_face, up_outer_frac_face, left_outer_frac_face], 2)
gmsh.model.setPhysicalName(2, 2, 'outletTemperature')

# %% [markdown]
# ## Generate mesh

# %%
# Generate mesh
gmsh.model.mesh.generate(3)

# Save mesh
filename = '3D_fracture_mesh.msh'
gmsh.write(filename)

gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 7 (Line)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Line)
# Info    : [ 10%] Meshing curve 10 (Line)
# Info    : [ 10%] Meshing curve 11 (Line)
# Info    : [ 10%] Meshing curve 12 (Line)
# Info    : [ 10%] Meshing curve 13 (Line)
# Info    : [ 10%] Meshing curve 14 (Line)
# Info    : [ 10%] Meshing curve 15 (Line)
# Info    : [ 10%] Meshing curve 16 (Line)
# Info    : [ 10%] Meshing curve 17 (Circle)
# Info    : [ 20%] Meshing curve 18 (Circle)
# Info    : [ 20%] Meshing curve 19 (Circle)
# Info    : [ 20%] Meshing curve 20 (Circle)
# Info    : [ 20%] Meshing curve 21 (Circle)
# Info    : [ 20%] Meshing curve 22 (Circle)
# Info    : [ 20%] Meshing curve 23 (Circle)
# Info    : [ 20%] Meshing curve 24 (Circle)
# Info    : [ 20%] Meshing curve 25 (Circle)
# Info    : [ 20%] Meshing curve 26 (Circle)
# Info    : [ 20%] Meshing curve 27 (Circle)
# Info    : [ 20%] Meshing curve 28 (Circle)
# Info    : [ 20%] Meshing curve 30 (Extruded)
# Info    : [ 20%] Meshing curve 31 (Extruded)
# Info    : [ 20%] Meshing curve 32 (Extruded)
# Info    : [ 20%] Meshing curve 33 (Extruded)
# Info    : [ 20%] Meshing curve 35 (Extruded)
# Info    : [ 30%] Meshing curve 36 (Extruded)
# Info    : [ 30%] Meshing curve 40 (Extruded)
# Info    : [ 30%] Meshing curve 44 (Extruded)
# Info    : [ 30%] Meshing curve 52 (Extruded)
# Info    : [ 30%] Meshing curve 53 (Extruded)
# Info    : [ 30%] Meshing curve 54 (Extruded)
# Info    : [ 30%] Meshing curve 58 (Extruded)
# Info    : [ 30%] Meshing curve 62 (Extruded)
# Info    : [ 30%] Meshing curve 74 (Extruded)
# Info    : [ 30%] Meshing curve 75 (Extruded)
# Info    : [ 30%] Meshing curve 76 (Extruded)
# Info    : [ 30%] Meshing curve 80 (Extruded)
# Info    : [ 30%] Meshing curve 84 (Extruded)
# Info    : [ 30%] Meshing curve 96 (Extruded)
# Info    : [ 30%] Meshing curve 98 (Extruded)
# Info    : [ 30%] Meshing curve 118 (Extruded)
# Info    : [ 40%] Meshing curve 119 (Extruded)
# Info    : [ 40%] Meshing curve 121 (Extruded)
# Info    : [ 40%] Meshing curve 123 (Extruded)
# Info    : [ 40%] Meshing curve 124 (Extruded)
# Info    : [ 40%] Meshing curve 140 (Extruded)
# Info    : [ 40%] Meshing curve 141 (Extruded)
# Info    : [ 40%] Meshing curve 146 (Extruded)
# Info    : [ 40%] Meshing curve 162 (Extruded)
# Info    : [ 40%] Meshing curve 163 (Extruded)
# Info    : [ 40%] Meshing curve 168 (Extruded)
# Info    : [ 40%] Meshing curve 184 (Extruded)
# Info    : [ 40%] Meshing curve 206 (Extruded)
# Info    : [ 40%] Meshing curve 207 (Extruded)
# Info    : [ 40%] Meshing curve 209 (Extruded)
# Info    : [ 40%] Meshing curve 211 (Extruded)
# Info    : [ 40%] Meshing curve 212 (Extruded)
# Info    : [ 50%] Meshing curve 228 (Extruded)
# Info    : [ 50%] Meshing curve 229 (Extruded)
# Info    : [ 50%] Meshing curve 234 (Extruded)
# Info    : [ 50%] Meshing curve 250 (Extruded)
# Info    : [ 50%] Meshing curve 251 (Extruded)
# Info    : [ 50%] Meshing curve 256 (Extruded)
# Info    : [ 50%] Meshing curve 272 (Extruded)
# Info    : [ 50%] Meshing curve 294 (Extruded)
# Info    : [ 50%] Meshing curve 295 (Extruded)
# Info    : [ 50%] Meshing curve 296 (Extruded)
# Info    : [ 50%] Meshing curve 297 (Extruded)
# Info    : [ 50%] Meshing curve 299 (Extruded)
# Info    : [ 50%] Meshing curve 300 (Extruded)
# Info    : [ 50%] Meshing curve 304 (Extruded)
# Info    : [ 50%] Meshing curve 308 (Extruded)
# Info    : [ 50%] Meshing curve 316 (Extruded)
# Info    : [ 60%] Meshing curve 317 (Extruded)
# Info    : [ 60%] Meshing curve 318 (Extruded)
# Info    : [ 60%] Meshing curve 322 (Extruded)
# Info    : [ 60%] Meshing curve 326 (Extruded)
# Info    : [ 60%] Meshing curve 338 (Extruded)
# Info    : [ 60%] Meshing curve 339 (Extruded)
# Info    : [ 60%] Meshing curve 340 (Extruded)
# Info    : [ 60%] Meshing curve 344 (Extruded)
# Info    : [ 60%] Meshing curve 348 (Extruded)
# Info    : [ 60%] Meshing curve 360 (Extruded)
# Info    : [ 60%] Meshing curve 362 (Extruded)
# Info    : [ 60%] Meshing curve 382 (Extruded)
# Info    : [ 60%] Meshing curve 383 (Extruded)
# Info    : [ 60%] Meshing curve 385 (Extruded)
# Info    : [ 60%] Meshing curve 387 (Extruded)
# Info    : [ 60%] Meshing curve 388 (Extruded)
# Info    : [ 70%] Meshing curve 404 (Extruded)
# Info    : [ 70%] Meshing curve 405 (Extruded)
# Info    : [ 70%] Meshing curve 410 (Extruded)
# Info    : [ 70%] Meshing curve 426 (Extruded)
# Info    : [ 70%] Meshing curve 427 (Extruded)
# Info    : [ 70%] Meshing curve 432 (Extruded)
# Info    : [ 70%] Meshing curve 448 (Extruded)
# Info    : [ 70%] Meshing curve 470 (Extruded)
# Info    : [ 70%] Meshing curve 471 (Extruded)
# Info    : [ 70%] Meshing curve 473 (Extruded)
# Info    : [ 70%] Meshing curve 475 (Extruded)
# Info    : [ 70%] Meshing curve 476 (Extruded)
# Info    : [ 70%] Meshing curve 492 (Extruded)
# Info    : [ 70%] Meshing curve 493 (Extruded)
# Info    : [ 70%] Meshing curve 498 (Extruded)
# Info    : [ 70%] Meshing curve 514 (Extruded)
# Info    : [ 80%] Meshing curve 515 (Extruded)
# Info    : [ 80%] Meshing curve 520 (Extruded)
# Info    : [ 80%] Meshing curve 536 (Extruded)
# Info    : [ 80%] Meshing curve 558 (Extruded)
# Info    : [ 80%] Meshing curve 559 (Extruded)
# Info    : [ 80%] Meshing curve 560 (Extruded)
# Info    : [ 80%] Meshing curve 561 (Extruded)
# Info    : [ 80%] Meshing curve 563 (Extruded)
# Info    : [ 80%] Meshing curve 564 (Extruded)
# Info    : [ 80%] Meshing curve 568 (Extruded)
# Info    : [ 80%] Meshing curve 572 (Extruded)
# Info    : [ 80%] Meshing curve 580 (Extruded)
# Info    : [ 80%] Meshing curve 581 (Extruded)
# Info    : [ 80%] Meshing curve 582 (Extruded)
# Info    : [ 80%] Meshing curve 586 (Extruded)
# Info    : [ 80%] Meshing curve 590 (Extruded)
# Info    : [ 90%] Meshing curve 602 (Extruded)
# Info    : [ 90%] Meshing curve 603 (Extruded)
# Info    : [ 90%] Meshing curve 604 (Extruded)
# Info    : [ 90%] Meshing curve 608 (Extruded)
# Info    : [ 90%] Meshing curve 612 (Extruded)
# Info    : [ 90%] Meshing curve 624 (Extruded)
# Info    : [ 90%] Meshing curve 626 (Extruded)
# Info    : [ 90%] Meshing curve 646 (Extruded)
# Info    : [ 90%] Meshing curve 647 (Extruded)
# Info    : [ 90%] Meshing curve 649 (Extruded)
# Info    : [ 90%] Meshing curve 651 (Extruded)
# Info    : [ 90%] Meshing curve 652 (Extruded)
# Info    : [ 90%] Meshing curve 668 (Extruded)
# Info    : [ 90%] Meshing curve 669 (Extruded)
# Info    : [ 90%] Meshing curve 674 (Extruded)
# Info    : [ 90%] Meshing curve 690 (Extruded)
# Info    : [100%] Meshing curve 691 (Extruded)
# Info    : [100%] Meshing curve 696 (Extruded)
# Info    : [100%] Meshing curve 712 (Extruded)
# Info    : [100%] Meshing curve 734 (Extruded)
# Info    : [100%] Meshing curve 735 (Extruded)
# Info    : [100%] Meshing curve 737 (Extruded)
# Info    : [100%] Meshing curve 739 (Extruded)
# Info    : [100%] Meshing curve 740 (Extruded)
# Info    : [100%] Meshing curve 756 (Extruded)
# Info    : [100%] Meshing curve 757 (Extruded)
# Info    : [100%] Meshing curve 762 (Extruded)
# Info    : [100%] Meshing curve 778 (Extruded)
# Info    : [100%] Meshing curve 779 (Extruded)
# Info    : [100%] Meshing curve 784 (Extruded)
# Info    : [100%] Meshing curve 800 (Extruded)
# Info    : Done meshing 1D (Wall 0.00480578s, CPU 0.001708s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Transfinite)
# Info    : [ 10%] Meshing surface 2 (Transfinite)
# Info    : [ 10%] Meshing surface 3 (Transfinite)
# Info    : [ 10%] Meshing surface 4 (Transfinite)
# Info    : [ 10%] Meshing surface 5 (Transfinite)
# Info    : [ 10%] Meshing surface 6 (Transfinite)
# Info    : [ 10%] Meshing surface 7 (Transfinite)
# Info    : [ 10%] Meshing surface 8 (Transfinite)
# Info    : [ 10%] Meshing surface 9 (Transfinite)
# Info    : [ 10%] Meshing surface 10 (Transfinite)
# Info    : [ 10%] Meshing surface 11 (Transfinite)
# Info    : [ 10%] Meshing surface 12 (Transfinite)
# Info    : [ 10%] Meshing surface 37 (Extruded)
# Info    : [ 10%] Meshing surface 41 (Extruded)
# Info    : [ 20%] Meshing surface 45 (Extruded)
# Info    : [ 20%] Meshing surface 49 (Extruded)
# Info    : [ 20%] Meshing surface 50 (Extruded)
# Info    : [ 20%] Meshing surface 59 (Extruded)
# Info    : [ 20%] Meshing surface 63 (Extruded)
# Info    : [ 20%] Meshing surface 67 (Extruded)
# Info    : [ 20%] Meshing surface 72 (Extruded)
# Info    : [ 20%] Meshing surface 81 (Extruded)
# Info    : [ 20%] Meshing surface 85 (Extruded)
# Info    : [ 20%] Meshing surface 89 (Extruded)
# Info    : [ 20%] Meshing surface 94 (Extruded)
# Info    : [ 20%] Meshing surface 103 (Extruded)
# Info    : [ 20%] Meshing surface 111 (Extruded)
# Info    : [ 30%] Meshing surface 116 (Extruded)
# Info    : [ 30%] Meshing surface 125 (Extruded)
# Info    : [ 30%] Meshing surface 129 (Extruded)
# Info    : [ 30%] Meshing surface 137 (Extruded)
# Info    : [ 30%] Meshing surface 138 (Extruded)
# Info    : [ 30%] Meshing surface 147 (Extruded)
# Info    : [ 30%] Meshing surface 151 (Extruded)
# Info    : [ 30%] Meshing surface 160 (Extruded)
# Info    : [ 30%] Meshing surface 169 (Extruded)
# Info    : [ 30%] Meshing surface 173 (Extruded)
# Info    : [ 30%] Meshing surface 182 (Extruded)
# Info    : [ 30%] Meshing surface 191 (Extruded)
# Info    : [ 30%] Meshing surface 204 (Extruded)
# Info    : [ 40%] Meshing surface 213 (Extruded)
# Info    : [ 40%] Meshing surface 217 (Extruded)
# Info    : [ 40%] Meshing surface 225 (Extruded)
# Info    : [ 40%] Meshing surface 226 (Extruded)
# Info    : [ 40%] Meshing surface 235 (Extruded)
# Info    : [ 40%] Meshing surface 239 (Extruded)
# Info    : [ 40%] Meshing surface 248 (Extruded)
# Info    : [ 40%] Meshing surface 257 (Extruded)
# Info    : [ 40%] Meshing surface 261 (Extruded)
# Info    : [ 40%] Meshing surface 270 (Extruded)
# Info    : [ 40%] Meshing surface 279 (Extruded)
# Info    : [ 40%] Meshing surface 292 (Extruded)
# Info    : [ 40%] Meshing surface 301 (Extruded)
# Info    : [ 50%] Meshing surface 305 (Extruded)
# Info    : [ 50%] Meshing surface 309 (Extruded)
# Info    : [ 50%] Meshing surface 313 (Extruded)
# Info    : [ 50%] Meshing surface 314 (Extruded)
# Info    : [ 50%] Meshing surface 323 (Extruded)
# Info    : [ 50%] Meshing surface 327 (Extruded)
# Info    : [ 50%] Meshing surface 331 (Extruded)
# Info    : [ 50%] Meshing surface 336 (Extruded)
# Info    : [ 50%] Meshing surface 345 (Extruded)
# Info    : [ 50%] Meshing surface 349 (Extruded)
# Info    : [ 50%] Meshing surface 353 (Extruded)
# Info    : [ 50%] Meshing surface 358 (Extruded)
# Info    : [ 50%] Meshing surface 367 (Extruded)
# Info    : [ 50%] Meshing surface 375 (Extruded)
# Info    : [ 60%] Meshing surface 380 (Extruded)
# Info    : [ 60%] Meshing surface 389 (Extruded)
# Info    : [ 60%] Meshing surface 393 (Extruded)
# Info    : [ 60%] Meshing surface 401 (Extruded)
# Info    : [ 60%] Meshing surface 402 (Extruded)
# Info    : [ 60%] Meshing surface 411 (Extruded)
# Info    : [ 60%] Meshing surface 415 (Extruded)
# Info    : [ 60%] Meshing surface 424 (Extruded)
# Info    : [ 60%] Meshing surface 433 (Extruded)
# Info    : [ 60%] Meshing surface 437 (Extruded)
# Info    : [ 60%] Meshing surface 446 (Extruded)
# Info    : [ 60%] Meshing surface 455 (Extruded)
# Info    : [ 60%] Meshing surface 468 (Extruded)
# Info    : [ 70%] Meshing surface 477 (Extruded)
# Info    : [ 70%] Meshing surface 481 (Extruded)
# Info    : [ 70%] Meshing surface 489 (Extruded)
# Info    : [ 70%] Meshing surface 490 (Extruded)
# Info    : [ 70%] Meshing surface 499 (Extruded)
# Info    : [ 70%] Meshing surface 503 (Extruded)
# Info    : [ 70%] Meshing surface 512 (Extruded)
# Info    : [ 70%] Meshing surface 521 (Extruded)
# Info    : [ 70%] Meshing surface 525 (Extruded)
# Info    : [ 70%] Meshing surface 534 (Extruded)
# Info    : [ 70%] Meshing surface 543 (Extruded)
# Info    : [ 70%] Meshing surface 556 (Extruded)
# Info    : [ 70%] Meshing surface 565 (Extruded)
# Info    : [ 80%] Meshing surface 569 (Extruded)
# Info    : [ 80%] Meshing surface 573 (Extruded)
# Info    : [ 80%] Meshing surface 577 (Extruded)
# Info    : [ 80%] Meshing surface 578 (Extruded)
# Info    : [ 80%] Meshing surface 587 (Extruded)
# Info    : [ 80%] Meshing surface 591 (Extruded)
# Info    : [ 80%] Meshing surface 595 (Extruded)
# Info    : [ 80%] Meshing surface 600 (Extruded)
# Info    : [ 80%] Meshing surface 609 (Extruded)
# Info    : [ 80%] Meshing surface 613 (Extruded)
# Info    : [ 80%] Meshing surface 617 (Extruded)
# Info    : [ 80%] Meshing surface 622 (Extruded)
# Info    : [ 80%] Meshing surface 631 (Extruded)
# Info    : [ 90%] Meshing surface 639 (Extruded)
# Info    : [ 90%] Meshing surface 644 (Extruded)
# Info    : [ 90%] Meshing surface 653 (Extruded)
# Info    : [ 90%] Meshing surface 657 (Extruded)
# Info    : [ 90%] Meshing surface 665 (Extruded)
# Info    : [ 90%] Meshing surface 666 (Extruded)
# Info    : [ 90%] Meshing surface 675 (Extruded)
# Info    : [ 90%] Meshing surface 679 (Extruded)
# Info    : [ 90%] Meshing surface 688 (Extruded)
# Info    : [ 90%] Meshing surface 697 (Extruded)
# Info    : [ 90%] Meshing surface 701 (Extruded)
# Info    : [ 90%] Meshing surface 710 (Extruded)
# Info    : [ 90%] Meshing surface 719 (Extruded)
# Info    : [100%] Meshing surface 732 (Extruded)
# Info    : [100%] Meshing surface 741 (Extruded)
# Info    : [100%] Meshing surface 745 (Extruded)
# Info    : [100%] Meshing surface 753 (Extruded)
# Info    : [100%] Meshing surface 754 (Extruded)
# Info    : [100%] Meshing surface 763 (Extruded)
# Info    : [100%] Meshing surface 767 (Extruded)
# Info    : [100%] Meshing surface 776 (Extruded)
# Info    : [100%] Meshing surface 785 (Extruded)
# Info    : [100%] Meshing surface 789 (Extruded)
# Info    : [100%] Meshing surface 798 (Extruded)
# Info    : [100%] Meshing surface 807 (Extruded)
# Info    : [100%] Meshing surface 820 (Extruded)
# Info    : Done meshing 2D (Wall 0.17003s, CPU 0.161635s)
# Info    : Meshing 3D...
# Info    : Meshing volume 1 (Extruded)
# Info    : Meshing volume 2 (Extruded)
# Info    : Meshing volume 3 (Extruded)
# Info    : Meshing volume 4 (Extruded)
# Info    : Meshing volume 5 (Extruded)
# Info    : Meshing volume 6 (Extruded)
# Info    : Meshing volume 7 (Extruded)
# Info    : Meshing volume 8 (Extruded)
# Info    : Meshing volume 9 (Extruded)
# Info    : Meshing volume 10 (Extruded)
# Info    : Meshing volume 11 (Extruded)
# Info    : Meshing volume 12 (Extruded)
# Info    : Meshing volume 13 (Extruded)
# Info    : Meshing volume 14 (Extruded)
# Info    : Meshing volume 15 (Extruded)
# Info    : Meshing volume 16 (Extruded)
# Info    : Meshing volume 17 (Extruded)
# Info    : Meshing volume 18 (Extruded)
# Info    : Meshing volume 19 (Extruded)
# Info    : Meshing volume 20 (Extruded)
# Info    : Meshing volume 21 (Extruded)
# Info    : Meshing volume 22 (Extruded)
# Info    : Meshing volume 23 (Extruded)
# Info    : Meshing volume 24 (Extruded)
# Info    : Meshing volume 25 (Extruded)
# Info    : Meshing volume 26 (Extruded)
# Info    : Meshing volume 27 (Extruded)
# Info    : Meshing volume 28 (Extruded)
# Info    : Meshing volume 29 (Extruded)
# Info    : Meshing volume 30 (Extruded)
# Info    : Meshing volume 31 (Extruded)
# Info    : Meshing volume 32 (Extruded)
# Info    : Meshing volume 33 (Extruded)
# Info    : Meshing volume 34 (Extruded)
# Info    : Meshing volume 35 (Extruded)
# Info    : Meshing volume 36 (Extruded)
# Info    : Done meshing 3D (Wall 0.708893s, CPU 0.68652s)
# Info    : Optimizing mesh...
# Info    : Done optimizing mesh (Wall 0.0109517s, CPU 0.011073s)
# Info    : 326804 nodes 377364 elements
# Info    : Writing '3D_fracture_mesh.msh'...
# Info    : Done writing '3D_fracture_mesh.msh'
